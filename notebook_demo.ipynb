# %%
from src.workflow import *

# %%
# Out:
# Text(value='', description='Prefix:')
# Text(value='', description='Name')
# Dropdown(description='Effect of the mutation (if known)in the ground state population.ref: reference to contra…
# Dropdown(description='Effect of the mutation (if known)in the most frequent alternativestate population.ref: r…
# IntText(value=0, description='Rank: 0')
# Button(description='Add to Dictionary', style=ButtonStyle())
# Button(description='Save to JSON', style=ButtonStyle())
# Output()

# %%
prefix = config.SYSTEM_NAME

# %%
build_msa(prefix)
# Out:
# If jackhmmer is in path, building MSA.
# JACKHMMER not found, not building MSA

# %%
optimizer_manager = OptimizerManager(config.SYSTEM_NAME)

# %%
variations = optimizer_manager.get_variation_regions()

# %%
optimizer_manager.get_parameter_set_variations()

# %%
optimizer_manager.plot_variation_regions()

# %%
best = optimizer_manager.get_best_parameter_set()
# Out:
# Peak range (69, 135) with Alt1 RMSD of 0.319 A for parameter 1024:2048 rejected: ground conformation has higher RMSD than alt1 conformation.
# Peak range (27, 42) with Alt1 RMSD of 0.319 A for parameter 1024:2048 rejected: ground conformation has higher RMSD than alt1 conformation.
# Peak range (135, 195) with Alt1 RMSD of 0.319 A for parameter 1024:2048 rejected: ground conformation has higher RMSD than alt1 conformation.
# Failed :(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 best = optimizer_manager.get_best_parameter_set()
#
# File ~\af2\src\workflow.py:79, in OptimizerManager.get_best_parameter_set(self)
#      75 def get_best_parameter_set(self) -> Dict[str, Any]:
#      76     predictions_path = os.path.join(config.PREDICTION_ROOT,
#      77                                     'results',
#      78                                     'af2_predictions')
# ---> 79     best_set = self.optimizer.make_final_decision(predictions_path)
#      80     return best_set
#
# File ~\af2\src\subsampling_optimization\subsamplingoptimizer.py:163, in SubsamplingOptimizer.make_final_decision(self, path)
#     158 final_results_path = os.path.join(PREDICTION_ROOT,
#     159                                   "results",
#     160                                   "optimization_results",
#     161                                   f"{self.prefix}_optimizer_results.pkl")
#     162 save_to_pickle(final_results_path, subsampling_parameters)
# --> 163 subsampling_parameters = self._reformat_final_decision(subsampling_parameters)
#     164 return subsampling_parameters
#
# File ~\af2\src\subsampling_optimization\subsamplingoptimizer.py:187, in SubsamplingOptimizer._reformat_final_decision(final_decision)
#     183         return obj.tolist()  # Convert ndarray to list
#     184     raise TypeError(f"Object of type '{type(obj).__name__}' is not JSON serializable")
#     186 reformatted = {'System Name': SYSTEM_NAME,
# --> 187                'max_seq': final_decision['parameters'].split(':')[0],
#     188                'extra_seq': final_decision['parameters'].split(':')[1],
#     189                'Highest Variation Range': final_decision['ranges'][0],
#     190                'Score': final_decision['scores'][0]}
#     191 path_reports = os.path.join('results',
#     192                             'reports',
#     193                             f"{SYSTEM_NAME}_best_subsampling_parameters.json")
#     195 with open(path_reports, 'w') as file:
#
# KeyError: 'parameters'

# %%
optimizer_manager.plot_parameter_set()

# %%
tester = MutantTester(config.SYSTEM_NAME)
tester.test_mutants()

# %%
tester.plot_results()

# %%
compare_mutation_clusters(config.SYSTEM_NAME)

# %%
mut_manager = MutationClusterManager(config.SYSTEM_NAME)
mut_manager.load_results()
mut_manager.init_cluster_comparer()
mut_manager.build_wt_model()
mut_manager.measure_effects()

# %%
mut_manager.plot_mutant_state_finder_results()

# %%
mut_manager.plot_cluster_results()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mut_manager.plot_cluster_results()
#
# NameError: name 'mut_manager' is not defined

# %%
mut_manager.plot_clustering_diffs()
